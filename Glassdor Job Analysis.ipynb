# %%
# importing libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# importing warnings & others related to display

import warnings
warnings.filterwarnings('ignore')

pd.set_option('display.max_columns', None)

from IPython.core.display import display, HTML
display(HTML('<style>.container {width:100% !important; }</style>'))
# Out:
# <style>.container {width:100% !important; }</style>

# %% [markdown]
# ### Loading & understanding Data

# %%
gd_df = pd.read_csv('Glassdoor jobs.csv')
gd_df
# Out:
#                                   Unnamed: 0                  Unnamed: 1  \
# 0                                        NaN                         NaN
# 1                                        NaN                         NaN
# 2                                Competitors                     Revenue
# 3    EmblemHealth, UnitedHealth Group, Aetna    Unknown / Non-Applicable
# 4                                         -1      $1 to $2 billion (USD)
# ..                                       ...                         ...
# 687                                       -1  $100 to $500 million (USD)
# 688                                       -1    Unknown / Non-Applicable
# 689           Luxoft, EPAM, Capgemini Invent   $50 to $100 million (USD)
# 690                                       -1    Unknown / Non-Applicable
# 691                                 Sequenom    Unknown / Non-Applicable
#
#                 GLASSDOOR JOBS                               Unnamed: 3  \
# ...

# %%
gd_df = pd.read_csv('Glassdoor jobs.csv', skiprows=3)
gd_df.head()
# Out:
#                                          Competitors  \
# 0            EmblemHealth, UnitedHealth Group, Aetna
# 1                                                 -1
# 2                                                 -1
# 3  MKS Instruments, Pfeiffer Vacuum, Agilent Tech...
# 4               Commerce Signals, Cardlytics, Yodlee
#
#                       Revenue             Sector  \
# 0    Unknown / Non-Applicable          Insurance
# 1      $1 to $2 billion (USD)  Business Services
# 2  $100 to $500 million (USD)  Business Services
# 3  $100 to $500 million (USD)      Manufacturing
# 4    Unknown / Non-Applicable  Business Services
#
#                                 Industry           Ownership Type  Founded  \
# 0                     Insurance Carriers   Nonprofit Organization     1993
# 1                 Research & Development         Company - Public     1968
# 2                             Consulting  Private Practice / Firm     1981
# ...

# %%
gd_df.drop(['index'], axis=1, inplace=True)
gd_df.head()
# Out:
#                                          Competitors  \
# 0            EmblemHealth, UnitedHealth Group, Aetna
# 1                                                 -1
# 2                                                 -1
# 3  MKS Instruments, Pfeiffer Vacuum, Agilent Tech...
# 4               Commerce Signals, Cardlytics, Yodlee
#
#                       Revenue             Sector  \
# 0    Unknown / Non-Applicable          Insurance
# 1      $1 to $2 billion (USD)  Business Services
# 2  $100 to $500 million (USD)  Business Services
# 3  $100 to $500 million (USD)      Manufacturing
# 4    Unknown / Non-Applicable  Business Services
#
#                                 Industry           Ownership Type  Founded  \
# 0                     Insurance Carriers   Nonprofit Organization     1993
# 1                 Research & Development         Company - Public     1968
# 2                             Consulting  Private Practice / Firm     1981
# ...

# %%
gd_df.columns
# Out:
# Index(['Competitors', 'Revenue', 'Sector', 'Industry', 'Ownership Type',
#        'Founded', 'Size', 'Headquarters', 'Location', 'Name', 'Rating',
#        'Description', 'Salary', 'Title'],
#       dtype='object')

# %%
cols = gd_df.columns
cols[0:11]
# Out:
# Index(['Competitors', 'Revenue', 'Sector', 'Industry', 'Ownership Type',
#        'Founded', 'Size', 'Headquarters', 'Location', 'Name', 'Rating'],
#       dtype='object')

# %%
cols[11:14]
# Out:
# Index(['Description', 'Salary', 'Title'], dtype='object')

# %%
l1 = 'C_' + cols[0:11]
l1
# Out:
# Index(['C_Competitors', 'C_Revenue', 'C_Sector', 'C_Industry',
#        'C_Ownership Type', 'C_Founded', 'C_Size', 'C_Headquarters',
#        'C_Location', 'C_Name', 'C_Rating'],
#       dtype='object')

# %%
l2 = 'J_' + cols[11:14]
l2
# Out:
# Index(['J_Description', 'J_Salary', 'J_Title'], dtype='object')

# %%
new_list = l1.append(l2)
new_list
# Out:
# Index(['C_Competitors', 'C_Revenue', 'C_Sector', 'C_Industry',
#        'C_Ownership Type', 'C_Founded', 'C_Size', 'C_Headquarters',
#        'C_Location', 'C_Name', 'C_Rating', 'J_Description', 'J_Salary',
#        'J_Title'],
#       dtype='object')

# %%
gd_df.columns = new_list
gd_df.columns
# Out:
# Index(['C_Competitors', 'C_Revenue', 'C_Sector', 'C_Industry',
#        'C_Ownership Type', 'C_Founded', 'C_Size', 'C_Headquarters',
#        'C_Location', 'C_Name', 'C_Rating', 'J_Description', 'J_Salary',
#        'J_Title'],
#       dtype='object')

# %%
gd_df.head()
# Out:
#                                        C_Competitors  \
# 0            EmblemHealth, UnitedHealth Group, Aetna
# 1                                                 -1
# 2                                                 -1
# 3  MKS Instruments, Pfeiffer Vacuum, Agilent Tech...
# 4               Commerce Signals, Cardlytics, Yodlee
#
#                     C_Revenue           C_Sector  \
# 0    Unknown / Non-Applicable          Insurance
# 1      $1 to $2 billion (USD)  Business Services
# 2  $100 to $500 million (USD)  Business Services
# 3  $100 to $500 million (USD)      Manufacturing
# 4    Unknown / Non-Applicable  Business Services
#
#                               C_Industry         C_Ownership Type  C_Founded  \
# 0                     Insurance Carriers   Nonprofit Organization       1993
# 1                 Research & Development         Company - Public       1968
# 2                             Consulting  Private Practice / Firm       1981
# ...

# %%
df2 = gd_df.copy()
df2.head()
# Out:
#                                        C_Competitors  \
# 0            EmblemHealth, UnitedHealth Group, Aetna
# 1                                                 -1
# 2                                                 -1
# 3  MKS Instruments, Pfeiffer Vacuum, Agilent Tech...
# 4               Commerce Signals, Cardlytics, Yodlee
#
#                     C_Revenue           C_Sector  \
# 0    Unknown / Non-Applicable          Insurance
# 1      $1 to $2 billion (USD)  Business Services
# 2  $100 to $500 million (USD)  Business Services
# 3  $100 to $500 million (USD)      Manufacturing
# 4    Unknown / Non-Applicable  Business Services
#
#                               C_Industry         C_Ownership Type  C_Founded  \
# 0                     Insurance Carriers   Nonprofit Organization       1993
# 1                 Research & Development         Company - Public       1968
# 2                             Consulting  Private Practice / Firm       1981
# ...

# %%
df2.add_prefix("Glassdoor_").head(5)
# Out:
#                              Glassdoor_C_Competitors  \
# 0            EmblemHealth, UnitedHealth Group, Aetna
# 1                                                 -1
# 2                                                 -1
# 3  MKS Instruments, Pfeiffer Vacuum, Agilent Tech...
# 4               Commerce Signals, Cardlytics, Yodlee
#
#           Glassdoor_C_Revenue Glassdoor_C_Sector  \
# 0    Unknown / Non-Applicable          Insurance
# 1      $1 to $2 billion (USD)  Business Services
# 2  $100 to $500 million (USD)  Business Services
# 3  $100 to $500 million (USD)      Manufacturing
# 4    Unknown / Non-Applicable  Business Services
#
#                     Glassdoor_C_Industry Glassdoor_C_Ownership Type  \
# 0                     Insurance Carriers     Nonprofit Organization
# 1                 Research & Development           Company - Public
# 2                             Consulting    Private Practice / Firm
# 3  Electrical & Electronic Manufacturing           Company - Public
# ...

# %%
gd_df.columns
# Out:
# Index(['C_Competitors', 'C_Revenue', 'C_Sector', 'C_Industry',
#        'C_Ownership Type', 'C_Founded', 'C_Size', 'C_Headquarters',
#        'C_Location', 'C_Name', 'C_Rating', 'J_Description', 'J_Salary',
#        'J_Title'],
#       dtype='object')

# %%
gd_df.columns[11:]
# Out:
# Index(['J_Description', 'J_Salary', 'J_Title'], dtype='object')

# %%
gd_df.columns[:11]
# Out:
# Index(['C_Competitors', 'C_Revenue', 'C_Sector', 'C_Industry',
#        'C_Ownership Type', 'C_Founded', 'C_Size', 'C_Headquarters',
#        'C_Location', 'C_Name', 'C_Rating'],
#       dtype='object')

# %%
list(gd_df.columns[11:]) + list(gd_df.columns[:11])
# Out:
# ['J_Description',
#  'J_Salary',
#  'J_Title',
#  'C_Competitors',
#  'C_Revenue',
#  'C_Sector',
#  'C_Industry',
#  'C_Ownership Type',
#  'C_Founded',
#  'C_Size',
#  'C_Headquarters',
#  'C_Location',
#  'C_Name',
#  'C_Rating']

# %%
gd_df[list(gd_df.columns[11:]) + list(gd_df.columns[:11])].head()
# Out:
#                                        J_Description  \
# 0  Description\n\nThe Senior Data Scientist is re...
# 1  Secure our Nation, Ignite your Future\n\nJoin ...
# 2  Overview\n\n\nAnalysis Group is one of the lar...
# 3  JOB DESCRIPTION:\n\nDo you have a passion for ...
# 4  Data Scientist\nAffinity Solutions / Marketing...
#
#                        J_Salary            J_Title  \
# 0  $137K-$171K (Glassdoor est.)  Sr Data Scientist
# 1  $137K-$171K (Glassdoor est.)     Data Scientist
# 2  $137K-$171K (Glassdoor est.)     Data Scientist
# 3  $137K-$171K (Glassdoor est.)     Data Scientist
# 4  $137K-$171K (Glassdoor est.)                NaN
#
#                                        C_Competitors  \
# 0            EmblemHealth, UnitedHealth Group, Aetna
# 1                                                 -1
# 2                                                 -1
# 3  MKS Instruments, Pfeiffer Vacuum, Agilent Tech...
# 4               Commerce Signals, Cardlytics, Yodlee
#
# ...

# %%
gd_df.head()
# Out:
#                                        C_Competitors  \
# 0            EmblemHealth, UnitedHealth Group, Aetna
# 1                                                 -1
# 2                                                 -1
# 3  MKS Instruments, Pfeiffer Vacuum, Agilent Tech...
# 4               Commerce Signals, Cardlytics, Yodlee
#
#                     C_Revenue           C_Sector  \
# 0    Unknown / Non-Applicable          Insurance
# 1      $1 to $2 billion (USD)  Business Services
# 2  $100 to $500 million (USD)  Business Services
# 3  $100 to $500 million (USD)      Manufacturing
# 4    Unknown / Non-Applicable  Business Services
#
#                               C_Industry         C_Ownership Type  C_Founded  \
# 0                     Insurance Carriers   Nonprofit Organization       1993
# 1                 Research & Development         Company - Public       1968
# 2                             Consulting  Private Practice / Firm       1981
# ...

# %%
gd_df = gd_df.loc[:, ::-1]
gd_df.columns
# Out:
# Index(['J_Title', 'J_Salary', 'J_Description', 'C_Rating', 'C_Name',
#        'C_Location', 'C_Headquarters', 'C_Size', 'C_Founded',
#        'C_Ownership Type', 'C_Industry', 'C_Sector', 'C_Revenue',
#        'C_Competitors'],
#       dtype='object')

# %%
gd_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 689 entries, 0 to 688
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   J_Title           684 non-null    object
#  1   J_Salary          689 non-null    object
#  2   J_Description     689 non-null    object
#  3   C_Rating          684 non-null    object
#  4   C_Name            689 non-null    object
#  5   C_Location        689 non-null    object
#  6   C_Headquarters    689 non-null    object
#  7   C_Size            689 non-null    object
#  8   C_Founded         689 non-null    int64
#  9   C_Ownership Type  689 non-null    object
#  10  C_Industry        689 non-null    object
#  11  C_Sector          689 non-null    object
#  12  C_Revenue         689 non-null    object
#  13  C_Competitors     689 non-null    object
# dtypes: int64(1), object(13)
# memory usage: 75.5+ KB

# %% [markdown]
# ### Data Cleaning

# %%
gd_df.isna().sum()
# Out:
# J_Title             5
# J_Salary            0
# J_Description       0
# C_Rating            5
# C_Name              0
# C_Location          0
# C_Headquarters      0
# C_Size              0
# C_Founded           0
# C_Ownership Type    0
# C_Industry          0
# C_Sector            0
# C_Revenue           0
# C_Competitors       0
# dtype: int64

# %%
gd_df['C_Rating'].isna()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 684    False
# 685    False
# 686     True
# 687    False
# 688    False
# Name: C_Rating, Length: 689, dtype: bool

# %%
gd_df[gd_df['C_Rating'].isna()]
# Out:
#                         J_Title                      J_Salary  \
# 49               Data Scientist   $75K-$131K (Glassdoor est.)
# 67               Data Scientist   $79K-$131K (Glassdoor est.)
# 157  Experienced Data Scientist  $101K-$165K (Glassdoor est.)
# 350              Data Scientist  $122K-$146K (Glassdoor est.)
# 686              Data Scientist   $79K-$131K (Glassdoor est.)
#
#                                          J_Description C_Rating  \
# 49   Company Description:\nWhats it like to work at...      NaN
# 67   As a member of the Data Science team, this rol...      NaN
# 157  *******Please Apply using this link: https://a...      NaN
# 350  What will you be doing?\n\nThe Contractor shal...      NaN
# 686  As a member of the Data Science team, this rol...      NaN
#
#                                         C_Name       C_Location  \
# 49                             Quick Base\n4.3    Cambridge, MA
# 67                          Grid Dynamics\n4.0  Santa Clara, CA
# ...

# %%
for i in (gd_df[~gd_df['C_Rating'].isna()]['C_Rating']):
    if len(i)>3:
        print(i)
# Out:
# 4.4*
# /3.7
# 3.8*/
# 2*+.9

# %%
l = []
for i in (gd_df['C_Rating']):
    try:
        pd.to_numeric(i)
    except ValueError:
        l.append(i)
        
print("Erronous Cases: ", l)
# Out:
# Erronous Cases:  ['4.4*', '/3.7', '3.8*/', '2*+.9']

# %%
gd_df[gd_df['C_Rating'].isna()].shape
# Out:
# (5, 14)

# %%
ix = gd_df[gd_df['C_Rating'].isna()].index
ix
# Out:
# Int64Index([49, 67, 157, 350, 686], dtype='int64')

# %%
lis = []
lis
# Out:
# []

# %%
len(ix)
# Out:
# 5

# %%
for i in range(0,len(ix)):
    lis.append(gd_df.iloc[ix[i]]['C_Name'].split('\n')[1])

# %%
lis
# Out:
# ['4.3', '4.0', '4.4', '4.7', '4.0']

# %%
gd_df.iloc[ix,3] = lis
gd_df.iloc[ix]
# Out:
#                         J_Title                      J_Salary  \
# 49               Data Scientist   $75K-$131K (Glassdoor est.)
# 67               Data Scientist   $79K-$131K (Glassdoor est.)
# 157  Experienced Data Scientist  $101K-$165K (Glassdoor est.)
# 350              Data Scientist  $122K-$146K (Glassdoor est.)
# 686              Data Scientist   $79K-$131K (Glassdoor est.)
#
#                                          J_Description C_Rating  \
# 49   Company Description:\nWhats it like to work at...      4.3
# 67   As a member of the Data Science team, this rol...      4.0
# 157  *******Please Apply using this link: https://a...      4.4
# 350  What will you be doing?\n\nThe Contractor shal...      4.7
# 686  As a member of the Data Science team, this rol...      4.0
#
#                                         C_Name       C_Location  \
# 49                             Quick Base\n4.3    Cambridge, MA
# 67                          Grid Dynamics\n4.0  Santa Clara, CA
# ...

# %%
gd_df.C_Rating.isna().sum()
# Out:
# 0

# %%
gd_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 689 entries, 0 to 688
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   J_Title           684 non-null    object
#  1   J_Salary          689 non-null    object
#  2   J_Description     689 non-null    object
#  3   C_Rating          689 non-null    object
#  4   C_Name            689 non-null    object
#  5   C_Location        689 non-null    object
#  6   C_Headquarters    689 non-null    object
#  7   C_Size            689 non-null    object
#  8   C_Founded         689 non-null    int64
#  9   C_Ownership Type  689 non-null    object
#  10  C_Industry        689 non-null    object
#  11  C_Sector          689 non-null    object
#  12  C_Revenue         689 non-null    object
#  13  C_Competitors     689 non-null    object
# dtypes: int64(1), object(13)
# memory usage: 75.5+ KB

# %%
def cleaner(str):
    cleaner_str = "".join(filter(lambda x:(x in "0123456789."),str))
    return float(cleaner_str)

# %%
gd_df['C_Rating'] = gd_df['C_Rating'].apply(cleaner)
gd_df['C_Rating'].dtype
# Out:
# dtype('float64')

# %%
gd_df.C_Rating.describe()
# Out:
# count    689.000000
# mean       3.672859
# std        0.953591
# min        1.000000
# 25%        3.400000
# 50%        3.800000
# 75%        4.300000
# max        5.600000
# Name: C_Rating, dtype: float64

# %%
gd_df.head()
# Out:
#              J_Title                      J_Salary  \
# 0  Sr Data Scientist  $137K-$171K (Glassdoor est.)
# 1     Data Scientist  $137K-$171K (Glassdoor est.)
# 2     Data Scientist  $137K-$171K (Glassdoor est.)
# 3     Data Scientist  $137K-$171K (Glassdoor est.)
# 4                NaN  $137K-$171K (Glassdoor est.)
#
#                                        J_Description  C_Rating  \
# 0  Description\n\nThe Senior Data Scientist is re...       3.1
# 1  Secure our Nation, Ignite your Future\n\nJoin ...       4.2
# 2  Overview\n\n\nAnalysis Group is one of the lar...       3.8
# 3  JOB DESCRIPTION:\n\nDo you have a passion for ...       3.5
# 4  Data Scientist\nAffinity Solutions / Marketing...       2.9
#
#                     C_Name     C_Location          C_Headquarters  \
# 0         Healthfirst\n3.1   New York, NY            New York, NY
# 1             ManTech\n4.2  Chantilly, VA             Herndon, VA
# 2      Analysis Group\n3.8     Boston, MA              Boston, MA
# ...

# %%
gd_df.eq(-1).sum()             # for integer
# Out:
# J_Title               0
# J_Salary              0
# J_Description         0
# C_Rating              0
# C_Name                0
# C_Location            0
# C_Headquarters        0
# C_Size                0
# C_Founded           119
# C_Ownership Type      0
# C_Industry            0
# C_Sector              0
# C_Revenue             0
# C_Competitors         0
# dtype: int64

# %%
gd_df.eq('-1').sum()          # for string
# Out:
# J_Title               0
# J_Salary              0
# J_Description         0
# C_Rating              0
# C_Name                0
# C_Location            0
# C_Headquarters       31
# C_Size               27
# C_Founded             0
# C_Ownership Type     27
# C_Industry           71
# C_Sector             71
# C_Revenue            27
# C_Competitors       512
# dtype: int64

# %%
(gd_df.eq(-1) + gd_df.eq('-1')).sum()                  # -1 : combined in the form integer & string
# Out:
# J_Title               0
# J_Salary              0
# J_Description         0
# C_Rating              0
# C_Name                0
# C_Location            0
# C_Headquarters       31
# C_Size               27
# C_Founded           119
# C_Ownership Type     27
# C_Industry           71
# C_Sector             71
# C_Revenue            27
# C_Competitors       512
# dtype: int64

# %%
gd_df
# Out:
#                                J_Title                      J_Salary  \
# 0                    Sr Data Scientist  $137K-$171K (Glassdoor est.)
# 1                       Data Scientist  $137K-$171K (Glassdoor est.)
# 2                       Data Scientist  $137K-$171K (Glassdoor est.)
# 3                       Data Scientist  $137K-$171K (Glassdoor est.)
# 4                                  NaN  $137K-$171K (Glassdoor est.)
# ..                                 ...                           ...
# 684                      Data Engineer   $79K-$131K (Glassdoor est.)
# 685                     Data Scientist   $79K-$131K (Glassdoor est.)
# 686                     Data Scientist   $79K-$131K (Glassdoor est.)
# 687  Data & Machine Learning Scientist   $79K-$131K (Glassdoor est.)
# 688  Data Scientist - Machine Learning   $79K-$131K (Glassdoor est.)
#
#                                          J_Description  C_Rating  \
# 0    Description\n\nThe Senior Data Scientist is re...       3.1
# ...

# %%
cols = gd_df.columns
cols
# Out:
# Index(['J_Title', 'J_Salary', 'J_Description', 'C_Rating', 'C_Name',
#        'C_Location', 'C_Headquarters', 'C_Size', 'C_Founded',
#        'C_Ownership Type', 'C_Industry', 'C_Sector', 'C_Revenue',
#        'C_Competitors'],
#       dtype='object')

# %%
gd_df.replace([-1,'-1'], np.nan, inplace=True)

# %%
gd_df.isna().sum()
# Out:
# J_Title               5
# J_Salary              0
# J_Description         0
# C_Rating              0
# C_Name                0
# C_Location            0
# C_Headquarters       31
# C_Size               27
# C_Founded           119
# C_Ownership Type     27
# C_Industry           71
# C_Sector             71
# C_Revenue            27
# C_Competitors       512
# dtype: int64

# %%
gd_df.head()
# Out:
#              J_Title                      J_Salary  \
# 0  Sr Data Scientist  $137K-$171K (Glassdoor est.)
# 1     Data Scientist  $137K-$171K (Glassdoor est.)
# 2     Data Scientist  $137K-$171K (Glassdoor est.)
# 3     Data Scientist  $137K-$171K (Glassdoor est.)
# 4                NaN  $137K-$171K (Glassdoor est.)
#
#                                        J_Description  C_Rating  \
# 0  Description\n\nThe Senior Data Scientist is re...       3.1
# 1  Secure our Nation, Ignite your Future\n\nJoin ...       4.2
# 2  Overview\n\n\nAnalysis Group is one of the lar...       3.8
# 3  JOB DESCRIPTION:\n\nDo you have a passion for ...       3.5
# 4  Data Scientist\nAffinity Solutions / Marketing...       2.9
#
#                     C_Name     C_Location          C_Headquarters  \
# 0         Healthfirst\n3.1   New York, NY            New York, NY
# 1             ManTech\n4.2  Chantilly, VA             Herndon, VA
# 2      Analysis Group\n3.8     Boston, MA              Boston, MA
# ...

# %%
gd_df.shape
# Out:
# (689, 14)

# %%
gd_df.dropna(axis=0, inplace=True)

# %%
gd_df.shape
# Out:
# (170, 14)

# %%
gd_df.isna().sum()
# Out:
# J_Title             0
# J_Salary            0
# J_Description       0
# C_Rating            0
# C_Name              0
# C_Location          0
# C_Headquarters      0
# C_Size              0
# C_Founded           0
# C_Ownership Type    0
# C_Industry          0
# C_Sector            0
# C_Revenue           0
# C_Competitors       0
# dtype: int64

# %%
gd_df.head()
# Out:
#                              J_Title                      J_Salary  \
# 0                  Sr Data Scientist  $137K-$171K (Glassdoor est.)
# 3                     Data Scientist  $137K-$171K (Glassdoor est.)
# 8   Staff Data Scientist - Analytics  $137K-$171K (Glassdoor est.)
# 10                    Data Scientist  $137K-$171K (Glassdoor est.)
# 11                    Data Scientist  $137K-$171K (Glassdoor est.)
#
#                                         J_Description  C_Rating  \
# 0   Description\n\nThe Senior Data Scientist is re...       3.1
# 3   JOB DESCRIPTION:\n\nDo you have a passion for ...       3.5
# 8   Intuit is seeking a Staff Data Scientist to co...       4.4
# 10  Join our team dedicated to developing and exec...       4.5
# 11  About Us\n\n\nInterested in working for a huma...       4.7
#
#                 C_Name       C_Location          C_Headquarters  \
# 0     Healthfirst\n3.1     New York, NY            New York, NY
# ...

# %%
gd_df.reset_index(drop=True, inplace=True)

# %%
gd_df
# Out:
#                                        J_Title                      J_Salary  \
# 0                            Sr Data Scientist  $137K-$171K (Glassdoor est.)
# 1                               Data Scientist  $137K-$171K (Glassdoor est.)
# 2             Staff Data Scientist - Analytics  $137K-$171K (Glassdoor est.)
# 3                               Data Scientist  $137K-$171K (Glassdoor est.)
# 4                               Data Scientist  $137K-$171K (Glassdoor est.)
# ..                                         ...                           ...
# 165  Product Data Scientist - Ads Data Science   $75K-$131K (Glassdoor est.)
# 166                             Data Scientist   $75K-$131K (Glassdoor est.)
# 167                               Data Analyst   $75K-$131K (Glassdoor est.)
# 168                        Global Data Analyst   $79K-$131K (Glassdoor est.)
# 169                             Data Scientist   $79K-$131K (Glassdoor est.)
#
# ...

# %% [markdown]
# ### Hierarchical indexing

# %%
df2 = gd_df.copy()
df2.head()
# Out:
#                             J_Title                      J_Salary  \
# 0                 Sr Data Scientist  $137K-$171K (Glassdoor est.)
# 1                    Data Scientist  $137K-$171K (Glassdoor est.)
# 2  Staff Data Scientist - Analytics  $137K-$171K (Glassdoor est.)
# 3                    Data Scientist  $137K-$171K (Glassdoor est.)
# 4                    Data Scientist  $137K-$171K (Glassdoor est.)
#
#                                        J_Description  C_Rating  \
# 0  Description\n\nThe Senior Data Scientist is re...       3.1
# 1  JOB DESCRIPTION:\n\nDo you have a passion for ...       3.5
# 2  Intuit is seeking a Staff Data Scientist to co...       4.4
# 3  Join our team dedicated to developing and exec...       4.5
# 4  About Us\n\n\nInterested in working for a huma...       4.7
#
#                C_Name       C_Location          C_Headquarters  \
# 0    Healthfirst\n3.1     New York, NY            New York, NY
# ...

# %%
gd_df['C_City'] = gd_df['C_Location'].apply(lambda x: x.split(",")[0])
gd_df.head()
# Out:
#                             J_Title                      J_Salary  \
# 0                 Sr Data Scientist  $137K-$171K (Glassdoor est.)
# 1                    Data Scientist  $137K-$171K (Glassdoor est.)
# 2  Staff Data Scientist - Analytics  $137K-$171K (Glassdoor est.)
# 3                    Data Scientist  $137K-$171K (Glassdoor est.)
# 4                    Data Scientist  $137K-$171K (Glassdoor est.)
#
#                                        J_Description  C_Rating  \
# 0  Description\n\nThe Senior Data Scientist is re...       3.1
# 1  JOB DESCRIPTION:\n\nDo you have a passion for ...       3.5
# 2  Intuit is seeking a Staff Data Scientist to co...       4.4
# 3  Join our team dedicated to developing and exec...       4.5
# 4  About Us\n\n\nInterested in working for a huma...       4.7
#
#                C_Name       C_Location          C_Headquarters  \
# 0    Healthfirst\n3.1     New York, NY            New York, NY
# ...

# %%
loc = list(gd_df.C_Location.unique())
print(loc)
# Out:
# ['New York, NY', 'Newton, MA', 'San Diego, CA', 'Herndon, VA', 'Saint Louis, MO', 'Richland, WA', 'Plano, TX', 'Appleton, WI', 'United States', 'Overland Park, KS', 'Santa Monica, CA', 'Portsmouth, NH', 'Cambridge, MA', 'San Francisco, CA', 'Fort Wayne, IN', 'Carson, CA', 'Santa Clara, CA', 'Winter Park, FL', 'Peoria, IL', 'Ipswich, MA', 'Carmel, IN', 'Washington, DC', 'Gaithersburg, MD', 'Denver, CO', 'Chantilly, VA', 'Reston, VA', 'Bethesda, MD', 'Dayton, OH', 'McLean, VA', 'Woodbridge, NJ', 'Vicksburg, MS', 'Blue Bell, PA', 'Chicago, IL', 'Redwood City, CA', 'San Carlos, CA', 'Waltham, MA', 'Fort Worth, TX', 'Fort Belvoir, VA', 'Oklahoma City, OK', 'Champaign, IL', 'Texas', 'Lebanon, IN', 'Melbourne, FL', 'Cleveland, OH', 'San Jose, CA', 'Danvers, MA', 'Livermore, CA', 'Northbrook, IL', 'Oshkosh, WI', 'Ann Arbor, MI', 'Richmond, VA', 'Boston, MA', 'Kent, OH', 'Laurel, MD', 'Fremont, CA', 'Indianapolis, IN', 'Oxnard, CA', 'Kansas City, MO', 'Manchester, NH', 'Atlanta, GA', 'Falls C
# ...

# %%
for i in loc:
    if "," not in i:
        print(i)
# Out:
# United States
# Texas

# %%
gd_df[gd_df['C_Location'].isin(['United States','Texas'])]
# Out:
#             J_Title                      J_Salary  \
# 9     Data Engineer   $75K-$131K (Glassdoor est.)
# 70   Data Scientist   $71K-$123K (Glassdoor est.)
# 131  Data Scientist  $212K-$331K (Glassdoor est.)
# 154  Data Scientist   $87K-$141K (Glassdoor est.)
#
#                                          J_Description  C_Rating  \
# 9    Chef Software is the industry leader in IT aut...       3.6
# 70   Who we are\n\n\nFueled by a fundamental belief...       3.8
# 131  Position: Data Scientist\nLocation: Denver\nSt...       3.6
# 154  Business Unit:\nCubic Transportation Systems\n...       3.3
#
#                    C_Name     C_Location   C_Headquarters  \
# 9               Chef\n3.6  United States      Seattle, WA
# 70            PayPal\n3.8          Texas     San Jose, CA
# 131  Creative Circle\n3.6  United States  Los Angeles, CA
# 154            Cubic\n3.3  United States    San Diego, CA
#
#                       C_Size  C_Founded   C_Ownership Type  \
# ...

# %%
gd_df[gd_df['C_Location'].isin(['United States','Texas'])].shape
# Out:
# (4, 15)

# %%
gd_df2 = gd_df[~(gd_df['C_Location'] == 'United States')].reset_index(drop=True)
gd_df2.head()
# Out:
#                             J_Title                      J_Salary  \
# 0                 Sr Data Scientist  $137K-$171K (Glassdoor est.)
# 1                    Data Scientist  $137K-$171K (Glassdoor est.)
# 2  Staff Data Scientist - Analytics  $137K-$171K (Glassdoor est.)
# 3                    Data Scientist  $137K-$171K (Glassdoor est.)
# 4                    Data Scientist  $137K-$171K (Glassdoor est.)
#
#                                        J_Description  C_Rating  \
# 0  Description\n\nThe Senior Data Scientist is re...       3.1
# 1  JOB DESCRIPTION:\n\nDo you have a passion for ...       3.5
# 2  Intuit is seeking a Staff Data Scientist to co...       4.4
# 3  Join our team dedicated to developing and exec...       4.5
# 4  About Us\n\n\nInterested in working for a huma...       4.7
#
#                C_Name       C_Location          C_Headquarters  \
# 0    Healthfirst\n3.1     New York, NY            New York, NY
# ...

# %%
gd_df2[gd_df2['C_Location'].isin(['United States','Texas'])]
# Out:
#            J_Title                     J_Salary  \
# 69  Data Scientist  $71K-$123K (Glassdoor est.)
#
#                                         J_Description  C_Rating       C_Name  \
# 69  Who we are\n\n\nFueled by a fundamental belief...       3.8  PayPal\n3.8
#
#    C_Location C_Headquarters            C_Size  C_Founded  C_Ownership Type  \
# 69      Texas   San Jose, CA  10000+ employees     1998.0  Company - Public
#
#    C_Industry                C_Sector           C_Revenue  \
# 69   Internet  Information Technology  $10+ billion (USD)
#
#             C_Competitors C_City
# 69  Square, Amazon, Apple  Texas

# %%
gd_df2.head()
# Out:
#                             J_Title                      J_Salary  \
# 0                 Sr Data Scientist  $137K-$171K (Glassdoor est.)
# 1                    Data Scientist  $137K-$171K (Glassdoor est.)
# 2  Staff Data Scientist - Analytics  $137K-$171K (Glassdoor est.)
# 3                    Data Scientist  $137K-$171K (Glassdoor est.)
# 4                    Data Scientist  $137K-$171K (Glassdoor est.)
#
#                                        J_Description  C_Rating  \
# 0  Description\n\nThe Senior Data Scientist is re...       3.1
# 1  JOB DESCRIPTION:\n\nDo you have a passion for ...       3.5
# 2  Intuit is seeking a Staff Data Scientist to co...       4.4
# 3  Join our team dedicated to developing and exec...       4.5
# 4  About Us\n\n\nInterested in working for a huma...       4.7
#
#                C_Name       C_Location          C_Headquarters  \
# 0    Healthfirst\n3.1     New York, NY            New York, NY
# ...

# %%
gd_df2.shape
# Out:
# (167, 15)

# %%
gd_df2['C_State'] = gd_df2[(gd_df2['C_Location'] != 'Texas')]['C_Location'].apply(lambda x: x.split(",")[1])

# %%
gd_df2.head()
# Out:
#                             J_Title                      J_Salary  \
# 0                 Sr Data Scientist  $137K-$171K (Glassdoor est.)
# 1                    Data Scientist  $137K-$171K (Glassdoor est.)
# 2  Staff Data Scientist - Analytics  $137K-$171K (Glassdoor est.)
# 3                    Data Scientist  $137K-$171K (Glassdoor est.)
# 4                    Data Scientist  $137K-$171K (Glassdoor est.)
#
#                                        J_Description  C_Rating  \
# 0  Description\n\nThe Senior Data Scientist is re...       3.1
# 1  JOB DESCRIPTION:\n\nDo you have a passion for ...       3.5
# 2  Intuit is seeking a Staff Data Scientist to co...       4.4
# 3  Join our team dedicated to developing and exec...       4.5
# 4  About Us\n\n\nInterested in working for a huma...       4.7
#
#                C_Name       C_Location          C_Headquarters  \
# 0    Healthfirst\n3.1     New York, NY            New York, NY
# ...

# %%
gd_df2.isnull().sum()
# Out:
# J_Title             0
# J_Salary            0
# J_Description       0
# C_Rating            0
# C_Name              0
# C_Location          0
# C_Headquarters      0
# C_Size              0
# C_Founded           0
# C_Ownership Type    0
# C_Industry          0
# C_Sector            0
# C_Revenue           0
# C_Competitors       0
# C_City              0
# C_State             1
# dtype: int64

# %%
gd_df2['C_State'].unique()
# Out:
# array([' NY', ' MA', ' CA', ' VA', ' MO', ' WA', ' TX', ' WI', ' KS',
#        ' NH', ' IN', ' FL', ' IL', ' DC', ' MD', ' CO', ' OH', ' NJ',
#        ' MS', ' PA', ' OK', nan, ' MI', ' GA', ' DE', ' OR', ' WV'],
#       dtype=object)

# %%
gd_df2['C_State'].fillna('TX',inplace=True)

# %%
gd_df2.isnull().sum()
# Out:
# J_Title             0
# J_Salary            0
# J_Description       0
# C_Rating            0
# C_Name              0
# C_Location          0
# C_Headquarters      0
# C_Size              0
# C_Founded           0
# C_Ownership Type    0
# C_Industry          0
# C_Sector            0
# C_Revenue           0
# C_Competitors       0
# C_City              0
# C_State             0
# dtype: int64

# %%
gd_df2 = gd_df2.sort_values('C_State')
gd_df2.head()
# Out:
#                                             J_Title  \
# 166                                  Data Scientist
# 28   Data Science Manager, Payment Acceptance - USA
# 30                 Staff Data Scientist - Analytics
# 33                             Staff Data Scientist
# 119                Data Analyst - Unilever Prestige
#
#                         J_Salary  \
# 166  $79K-$131K (Glassdoor est.)
# 28   $79K-$131K (Glassdoor est.)
# 30   $99K-$132K (Glassdoor est.)
# 33   $99K-$132K (Glassdoor est.)
# 119  $69K-$116K (Glassdoor est.)
#
#                                          J_Description  C_Rating  \
# 166  As a member of the Data Science team, this rol...       4.0
# 28   Build out rigorous observability and optimizat...       4.0
# 30   Intuit is seeking a Staff Data Scientist to co...       4.4
# 33   Intuit is hiring a Senior Data scientist to fo...       4.4
# 119  Data Analyst - Unilever Prestige\nJob Code\n\n...       3.8
#
# ...

# %%
gd_df2.set_index(['C_State','C_City'], drop=False, inplace = True)

# %%
gd_df2.head()
# Out:
#                                                               J_Title  \
# C_State C_City
#  CA     Santa Clara                                    Data Scientist
#         San Francisco  Data Science Manager, Payment Acceptance - USA
#         San Diego                    Staff Data Scientist - Analytics
#         San Diego                                Staff Data Scientist
#         Carson                       Data Analyst - Unilever Prestige
#
#                                           J_Salary  \
# C_State C_City
#  CA     Santa Clara    $79K-$131K (Glassdoor est.)
#         San Francisco  $79K-$131K (Glassdoor est.)
#         San Diego      $99K-$132K (Glassdoor est.)
#         San Diego      $99K-$132K (Glassdoor est.)
#         Carson         $69K-$116K (Glassdoor est.)
#
#                                                            J_Description  \
# C_State C_City
#  CA     Santa Clara    As a member of the Data Science team, this rol...
# ...

# %%
gd_df2.J_Salary.unique()
# Out:
# array(['$79K-$131K (Glassdoor est.)', '$99K-$132K (Glassdoor est.)',
#        '$69K-$116K (Glassdoor est.)', '$124K-$198K (Glassdoor est.)',
#        '$110K-$163K (Glassdoor est.)', '$122K-$146K (Glassdoor est.)',
#        '$101K-$165K (Glassdoor est.)', '$79K-$147K (Glassdoor est.)',
#        '$141K-$225K (Glassdoor est.)', '$91K-$150K (Glassdoor est.)',
#        '$56K-$97K (Glassdoor est.)', '$90K-$124K (Glassdoor est.)',
#        '$31K-$56K (Glassdoor est.)', '$66K-$112K (Glassdoor est.)',
#        '$75K-$131K (Glassdoor est.)', '$138K-$158K (Glassdoor est.)',
#        '$128K-$201K (Glassdoor est.)', '$92K-$155K (Glassdoor est.)',
#        '$137K-$171K (Glassdoor est.)', '$212K-$331K (Glassdoor est.)',
#        '$95K-$119K (Glassdoor est.)', '$105K-$167K (Glassdoor est.)',
#        '$112K-$116K (Glassdoor est.)', '$90K-$109K (Glassdoor est.)',
#        '$80K-$132K (Glassdoor est.)', '$87K-$141K (Glassdoor est.)',
# ...

# %%
import re                                                               # REGEX
re.sub('[^0-9-]','',"$79K-$131K (Glassdoor est.)")
# Out:
# '79-131'

# %%
gd_df2['Salary Estimate'] = gd_df2['J_Salary'].apply(lambda x: re.sub('[^0-9-]','',x))
gd_df2.head()
# Out:
#                                                               J_Title  \
# C_State C_City
#  CA     Santa Clara                                    Data Scientist
#         San Francisco  Data Science Manager, Payment Acceptance - USA
#         San Diego                    Staff Data Scientist - Analytics
#         San Diego                                Staff Data Scientist
#         Carson                       Data Analyst - Unilever Prestige
#
#                                           J_Salary  \
# C_State C_City
#  CA     Santa Clara    $79K-$131K (Glassdoor est.)
#         San Francisco  $79K-$131K (Glassdoor est.)
#         San Diego      $99K-$132K (Glassdoor est.)
#         San Diego      $99K-$132K (Glassdoor est.)
#         Carson         $69K-$116K (Glassdoor est.)
#
#                                                            J_Description  \
# C_State C_City
#  CA     Santa Clara    As a member of the Data Science team, this rol...
# ...

# %%
gd_df2.insert(2, 'Min_Salary', gd_df2['Salary Estimate'].apply(lambda x: float(x.split("-")[0])))
gd_df2.head()
# Out:
#                                                               J_Title  \
# C_State C_City
#  CA     Santa Clara                                    Data Scientist
#         San Francisco  Data Science Manager, Payment Acceptance - USA
#         San Diego                    Staff Data Scientist - Analytics
#         San Diego                                Staff Data Scientist
#         Carson                       Data Analyst - Unilever Prestige
#
#                                           J_Salary  Min_Salary  \
# C_State C_City
#  CA     Santa Clara    $79K-$131K (Glassdoor est.)        79.0
#         San Francisco  $79K-$131K (Glassdoor est.)        79.0
#         San Diego      $99K-$132K (Glassdoor est.)        99.0
#         San Diego      $99K-$132K (Glassdoor est.)        99.0
#         Carson         $69K-$116K (Glassdoor est.)        69.0
#
#                                                            J_Description  \
# C_State C_City
# ...

# %%
gd_df2.insert(3, 'Max_Salary', gd_df2['Salary Estimate'].apply(lambda x: float(x.split("-")[1])))
gd_df2.head()
# Out:
#                                                               J_Title  \
# C_State C_City
#  CA     Santa Clara                                    Data Scientist
#         San Francisco  Data Science Manager, Payment Acceptance - USA
#         San Diego                    Staff Data Scientist - Analytics
#         San Diego                                Staff Data Scientist
#         Carson                       Data Analyst - Unilever Prestige
#
#                                           J_Salary  Min_Salary  Max_Salary  \
# C_State C_City
#  CA     Santa Clara    $79K-$131K (Glassdoor est.)        79.0       131.0
#         San Francisco  $79K-$131K (Glassdoor est.)        79.0       131.0
#         San Diego      $99K-$132K (Glassdoor est.)        99.0       132.0
#         San Diego      $99K-$132K (Glassdoor est.)        99.0       132.0
#         Carson         $69K-$116K (Glassdoor est.)        69.0       116.0
#
# ...

# %%
gd_df2[['Min_Salary','Max_Salary']].describe()
# Out:
#        Min_Salary  Max_Salary
# count  167.000000  167.000000
# mean    97.467066  145.862275
# std     32.720942   46.655094
# min     31.000000   56.000000
# 25%     79.000000  123.000000
# 50%     91.000000  132.000000
# 75%    112.000000  163.000000
# max    212.000000  331.000000

# %%
df3 = gd_df2.copy()
df3.head()
# Out:
#                                                               J_Title  \
# C_State C_City
#  CA     Santa Clara                                    Data Scientist
#         San Francisco  Data Science Manager, Payment Acceptance - USA
#         San Diego                    Staff Data Scientist - Analytics
#         San Diego                                Staff Data Scientist
#         Carson                       Data Analyst - Unilever Prestige
#
#                                           J_Salary  Min_Salary  Max_Salary  \
# C_State C_City
#  CA     Santa Clara    $79K-$131K (Glassdoor est.)        79.0       131.0
#         San Francisco  $79K-$131K (Glassdoor est.)        79.0       131.0
#         San Diego      $99K-$132K (Glassdoor est.)        99.0       132.0
#         San Diego      $99K-$132K (Glassdoor est.)        99.0       132.0
#         Carson         $69K-$116K (Glassdoor est.)        69.0       116.0
#
# ...

# %%
df3['MinSalRange'] = pd.cut(gd_df2['Min_Salary'], bins=[50,100,200,300], labels=['Low','Medium','High'])

# %%
df3.head()
# Out:
#                                                               J_Title  \
# C_State C_City
#  CA     Santa Clara                                    Data Scientist
#         San Francisco  Data Science Manager, Payment Acceptance - USA
#         San Diego                    Staff Data Scientist - Analytics
#         San Diego                                Staff Data Scientist
#         Carson                       Data Analyst - Unilever Prestige
#
#                                           J_Salary  Min_Salary  Max_Salary  \
# C_State C_City
#  CA     Santa Clara    $79K-$131K (Glassdoor est.)        79.0       131.0
#         San Francisco  $79K-$131K (Glassdoor est.)        79.0       131.0
#         San Diego      $99K-$132K (Glassdoor est.)        99.0       132.0
#         San Diego      $99K-$132K (Glassdoor est.)        99.0       132.0
#         Carson         $69K-$116K (Glassdoor est.)        69.0       116.0
#
# ...

# %%
df3.MinSalRange.value_counts()
# Out:
# Low       103
# Medium     54
# High        5
# Name: MinSalRange, dtype: int64

# %%
df3['MaxSalRange'] = pd.cut(gd_df2['Max_Salary'], bins=3, labels = ['Low','Medium','High']).drop('Max_SalRange')
df3.head()
# Out:
#                                                               J_Title  \
# C_State C_City
#  CA     Santa Clara                                    Data Scientist
#         San Francisco  Data Science Manager, Payment Acceptance - USA
#         San Diego                    Staff Data Scientist - Analytics
#         San Diego                                Staff Data Scientist
#         Carson                       Data Analyst - Unilever Prestige
#
#                                           J_Salary  Min_Salary  Max_Salary  \
# C_State C_City
#  CA     Santa Clara    $79K-$131K (Glassdoor est.)        79.0       131.0
#         San Francisco  $79K-$131K (Glassdoor est.)        79.0       131.0
#         San Diego      $99K-$132K (Glassdoor est.)        99.0       132.0
#         San Diego      $99K-$132K (Glassdoor est.)        99.0       132.0
#         Carson         $69K-$116K (Glassdoor est.)        69.0       116.0
#
# ...

# %%
df3.MaxSalRange.value_counts()
# Out:
# Low       105
# Medium     57
# High        5
# Name: MaxSalRange, dtype: int64
